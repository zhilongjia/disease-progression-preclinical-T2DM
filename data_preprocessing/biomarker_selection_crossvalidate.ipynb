# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
import statsmodels.api as sm
from scipy.stats import t

# %%
dm_type = 'pre'
df = pd.read_csv(f'data/data_balanced/data_t2dm_{dm_type}_balanced_no_outliers.csv')
# df = pd.read_csv('data/data_balanced/data_t2dm_biomarker_imputed.csv')
df_bio_names = pd.read_csv('data/biomarker_field.csv')
df_bio_names = df_bio_names[['Biomarker', 'Field', 'Units']]

# %%
print(df['t2dm'].value_counts())
# Out:
# t2dm
# 1    20277
# 0    20277
# Name: count, dtype: int64

# %%
biomarkers = df.columns[11:len(df.columns) - 2]
print(biomarkers)
# Out:
# Index(['BMI', 'SBP', 'DBP', 'WBC', 'RBC', 'Hgb', 'Hct', 'MCV', 'MCH', 'MCHC',
#        'RDW', 'PLT', 'PCT', 'MPV', 'PDW', 'LYM', 'MONO', 'NEUT', 'EOS', 'BASO',
#        'NRBC', 'LYMP', 'MONOP', 'NEUTP', 'EOSP', 'BASOP', 'NRBCP', 'RETP',
#        'RET', 'MRV', 'MSCV', 'IRF', 'HLS_ReticP', 'HLS_Retic',
#        'Urine_creatinine', 'Urine_potassium', 'Urine_sodium', 'Albumin', 'ALP',
#        'ALT', 'ApoA', 'ApoB', 'AST', 'DBIL', 'Urea', 'Calcium', 'CHOL',
#        'Creatinine', 'CRP', 'CysC', 'Glucose', 'HbA1c', 'HDLc', 'IGF_1',
#        'LDLc', 'Lpa', 'Phosphate', 'TBIL', 'Testosterone', 'TP', 'TG', 'Urate',
#        'Vitamin_D', 'TyG'],
#       dtype='object')

# %%
# z-score normalization
from utils import normalize_by_controls
df_zscored = normalize_by_controls(df, 't2dm', biomarkers)

# %%
# cross validation 10-fold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# %%
beta = np.zeros((len(biomarkers), 10))
p_values = np.ones((len(biomarkers), 10))
i = 0
for tr_idx, te_idx in skf.split(df_zscored[biomarkers], df_zscored['t2dm']):
    df_data = df_zscored.iloc[te_idx]
    for j, biomarker in enumerate(biomarkers):
        bio = biomarkers[j]
        X = np.asarray(df_data[bio])
        y = np.asarray(df_data['t2dm'])
        X = sm.add_constant(X.reshape(-1, 1))
        print(f'fold {i + 1}, biomarker = {bio}')
        try:
            model = sm.Logit(y, X)
            result = model.fit()
            p_values[j, i] = result.pvalues[1]
            beta[j, i] = result.params[1]
        except Exception as e:
            print(e)
            # except:
            #     print('Error')
            #     p_values[j, i] = 1
            #     beta[j, i] = np.nan
    i += 1
# Out:
# fold 1, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.611467
#          Iterations 5
# fold 1, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.686797
#          Iterations 4
# fold 1, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.688616
#          Iterations 4
# fold 1, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.671352
#          Iterations 4
# fold 1, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.686851
#          Iterations 4
# fold 1, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.692545
#          Iterations 3
# fold 1, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692040
#          Iterations 3
# fold 1, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.685448
#          Iterations 4
# fold 1, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.685180
#          Iterations 4
# fold 1, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.692490
#          Iterations 3
# fold 1, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.690642
#          Iterations 4
# fold 1, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.692217
#          Iterations 3
# fold 1, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.691633
#          Iterations 4
# fold 1, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.693031
#          Iterations 3
# fold 1, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.691741
#          Iterations 4
# fold 1, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.675872
#          Iterations 4
# fold 1, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.686021
#          Iterations 4
# fold 1, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.681386
#          Iterations 4
# fold 1, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.688659
#          Iterations 4
# fold 1, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.692342
#          Iterations 3
# fold 1, biomarker = NRBC
# exog contains inf or nans
# fold 1, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.692860
#          Iterations 3
# fold 1, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692526
#          Iterations 3
# fold 1, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693034
#          Iterations 3
# fold 1, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692824
#          Iterations 3
# fold 1, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.692921
#          Iterations 3
# fold 1, biomarker = NRBCP
# exog contains inf or nans
# fold 1, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.664087
#          Iterations 5
# fold 1, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.659081
#          Iterations 5
# fold 1, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.692214
#          Iterations 3
# fold 1, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.684565
#          Iterations 4
# fold 1, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.673529
#          Iterations 4
# fold 1, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.658172
#          Iterations 5
# fold 1, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.654014
#          Iterations 5
# fold 1, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.686562
#          Iterations 4
# fold 1, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.692444
#          Iterations 3
# fold 1, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.682984
#          Iterations 4
# fold 1, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.693041
#          Iterations 3
# fold 1, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.691558
#          Iterations 4
# fold 1, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.669723
#          Iterations 5
# fold 1, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.669980
#          Iterations 5
# fold 1, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.690737
#          Iterations 4
# fold 1, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.689716
#          Iterations 4
# fold 1, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.692815
#          Iterations 3
# fold 1, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.693028
#          Iterations 3
# fold 1, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.692176
#          Iterations 3
# fold 1, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.678143
#          Iterations 4
# fold 1, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.693106
#          Iterations 3
# fold 1, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.677010
#          Iterations 5
# fold 1, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.683114
#          Iterations 4
# fold 1, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.632450
#          Iterations 6
# fold 1, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.496314
#          Iterations 6
# fold 1, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.650270
#          Iterations 5
# fold 1, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.690280
#          Iterations 4
# fold 1, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.683484
#          Iterations 4
# fold 1, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.693134
#          Iterations 3
# fold 1, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.692865
#          Iterations 3
# fold 1, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.689806
#          Iterations 4
# fold 1, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.689926
#          Iterations 4
# fold 1, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.692217
#          Iterations 3
# fold 1, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.669167
#          Iterations 5
# fold 1, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.676529
#          Iterations 4
# fold 1, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.677875
#          Iterations 4
# fold 1, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.645972
#          Iterations 5
# fold 2, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.615807
#          Iterations 5
# fold 2, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.691262
#          Iterations 4
# fold 2, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.691750
#          Iterations 3
# fold 2, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.674287
#          Iterations 4
# fold 2, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.690497
#          Iterations 4
# fold 2, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.692928
#          Iterations 3
# fold 2, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692733
#          Iterations 3
# fold 2, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.689690
#          Iterations 4
# fold 2, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.689410
#          Iterations 4
# fold 2, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.692721
#          Iterations 3
# fold 2, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.690885
#          Iterations 4
# fold 2, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.692757
#          Iterations 3
# fold 2, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692245
#          Iterations 3
# fold 2, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692878
#          Iterations 3
# fold 2, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.691454
#          Iterations 4
# fold 2, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.682225
#          Iterations 4
# fold 2, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.686561
#          Iterations 4
# fold 2, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.681392
#          Iterations 4
# fold 2, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.687797
#          Iterations 4
# fold 2, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.692386
#          Iterations 3
# fold 2, biomarker = NRBC
# exog contains inf or nans
# fold 2, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.693143
#          Iterations 3
# fold 2, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692686
#          Iterations 3
# fold 2, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693131
#          Iterations 3
# fold 2, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692753
#          Iterations 3
# fold 2, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693037
#          Iterations 3
# fold 2, biomarker = NRBCP
# exog contains inf or nans
# fold 2, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.668775
#          Iterations 4
# fold 2, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.667207
#          Iterations 5
# fold 2, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.692677
#          Iterations 3
# fold 2, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.687419
#          Iterations 4
# fold 2, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.669744
#          Iterations 4
# fold 2, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.659522
#          Iterations 5
# fold 2, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.656989
#          Iterations 5
# fold 2, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.685413
#          Iterations 4
# fold 2, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.690930
#          Iterations 4
# fold 2, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.683185
#          Iterations 4
# fold 2, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.693146
#          Iterations 2
# fold 2, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.690311
#          Iterations 4
# fold 2, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.673616
#          Iterations 5
# fold 2, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.673067
#          Iterations 4
# fold 2, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.688113
#          Iterations 4
# fold 2, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.690474
#          Iterations 4
# fold 2, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693147
#          Iterations 2
# fold 2, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.692980
#          Iterations 3
# fold 2, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.690261
#          Iterations 4
# fold 2, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.673241
#          Iterations 4
# fold 2, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.692877
#          Iterations 3
# fold 2, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.682869
#          Iterations 5
# fold 2, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.682753
#          Iterations 4
# fold 2, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.635375
#          Iterations 6
# fold 2, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.503554
#          Iterations 6
# fold 2, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.658356
#          Iterations 5
# fold 2, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.691535
#          Iterations 4
# fold 2, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.678776
#          Iterations 4
# fold 2, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.692955
#          Iterations 3
# fold 2, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.692230
#          Iterations 3
# fold 2, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.691924
#          Iterations 4
# fold 2, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.691151
#          Iterations 4
# fold 2, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.690564
#          Iterations 4
# fold 2, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.673886
#          Iterations 5
# fold 2, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.678586
#          Iterations 4
# fold 2, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.682291
#          Iterations 4
# fold 2, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.652279
#          Iterations 5
# fold 3, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.617717
#          Iterations 5
# fold 3, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.691448
#          Iterations 4
# fold 3, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.691411
#          Iterations 4
# fold 3, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.674273
#          Iterations 4
# fold 3, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.692135
#          Iterations 3
# fold 3, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.693135
#          Iterations 3
# fold 3, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.693138
#          Iterations 3
# fold 3, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.690376
#          Iterations 4
# fold 3, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.691171
#          Iterations 4
# fold 3, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.693147
#          Iterations 2
# fold 3, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.691294
#          Iterations 4
# fold 3, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.692863
#          Iterations 3
# fold 3, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692339
#          Iterations 3
# fold 3, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692886
#          Iterations 3
# fold 3, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.690160
#          Iterations 4
# fold 3, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.679317
#          Iterations 4
# fold 3, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.687345
#          Iterations 4
# fold 3, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.682627
#          Iterations 4
# fold 3, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.687769
#          Iterations 4
# fold 3, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.692185
#          Iterations 4
# fold 3, biomarker = NRBC
# exog contains inf or nans
# fold 3, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.692795
#          Iterations 3
# fold 3, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692285
#          Iterations 3
# fold 3, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.692933
#          Iterations 3
# fold 3, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692554
#          Iterations 3
# fold 3, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.692905
#          Iterations 3
# fold 3, biomarker = NRBCP
# exog contains inf or nans
# fold 3, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.660973
#          Iterations 5
# fold 3, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.660724
#          Iterations 5
# fold 3, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.692305
#          Iterations 3
# fold 3, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.688590
#          Iterations 4
# fold 3, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.665139
#          Iterations 5
# fold 3, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.651116
#          Iterations 5
# fold 3, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.650663
#          Iterations 5
# fold 3, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.688397
#          Iterations 4
# fold 3, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.692325
#          Iterations 3
# fold 3, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.685364
#          Iterations 4
# fold 3, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.693147
#          Iterations 2
# fold 3, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.690970
#          Iterations 4
# fold 3, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.672200
#          Iterations 5
# fold 3, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.675647
#          Iterations 4
# fold 3, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.688583
#          Iterations 4
# fold 3, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.690088
#          Iterations 4
# fold 3, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693100
#          Iterations 3
# fold 3, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.692563
#          Iterations 3
# fold 3, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.692420
#          Iterations 3
# fold 3, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.674140
#          Iterations 4
# fold 3, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.692316
#          Iterations 3
# fold 3, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.674425
#          Iterations 5
# fold 3, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.684989
#          Iterations 4
# fold 3, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.622149
#          Iterations 6
# fold 3, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.493238
#          Iterations 6
# fold 3, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.657352
#          Iterations 5
# fold 3, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.690353
#          Iterations 4
# fold 3, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.678923
#          Iterations 4
# fold 3, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.693123
#          Iterations 3
# fold 3, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.693101
#          Iterations 3
# fold 3, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.691291
#          Iterations 4
# fold 3, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.688431
#          Iterations 4
# fold 3, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.691726
#          Iterations 4
# fold 3, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.672161
#          Iterations 5
# fold 3, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.674877
#          Iterations 4
# fold 3, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.683824
#          Iterations 4
# fold 3, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.644641
#          Iterations 5
# fold 4, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.608564
#          Iterations 5
# fold 4, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.690485
#          Iterations 4
# fold 4, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.690880
#          Iterations 4
# fold 4, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.667814
#          Iterations 5
# fold 4, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.690076
#          Iterations 4
# fold 4, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.693034
#          Iterations 3
# fold 4, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.693019
#          Iterations 3
# fold 4, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.686906
#          Iterations 4
# fold 4, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.688292
#          Iterations 4
# fold 4, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.693134
#          Iterations 3
# fold 4, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.689097
#          Iterations 4
# fold 4, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.693050
#          Iterations 3
# fold 4, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692711
#          Iterations 3
# fold 4, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692496
#          Iterations 3
# fold 4, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.691058
#          Iterations 4
# fold 4, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.676298
#          Iterations 4
# fold 4, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.685443
#          Iterations 4
# fold 4, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.678076
#          Iterations 4
# fold 4, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.688809
#          Iterations 4
# fold 4, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.690718
#          Iterations 4
# fold 4, biomarker = NRBC
# exog contains inf or nans
# fold 4, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.693109
#          Iterations 3
# fold 4, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692364
#          Iterations 3
# fold 4, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693144
#          Iterations 3
# fold 4, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692942
#          Iterations 3
# fold 4, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693061
#          Iterations 3
# fold 4, biomarker = NRBCP
# exog contains inf or nans
# fold 4, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.665522
#          Iterations 5
# fold 4, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.663052
#          Iterations 5
# fold 4, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.691214
#          Iterations 4
# fold 4, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.687534
#          Iterations 4
# fold 4, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.665152
#          Iterations 5
# fold 4, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.656110
#          Iterations 5
# fold 4, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.653672
#          Iterations 5
# fold 4, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.688279
#          Iterations 4
# fold 4, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.692923
#          Iterations 3
# fold 4, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.687405
#          Iterations 4
# fold 4, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.692629
#          Iterations 3
# fold 4, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.689757
#          Iterations 4
# fold 4, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.661718
#          Iterations 5
# fold 4, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.675901
#          Iterations 4
# fold 4, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.689479
#          Iterations 4
# fold 4, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.687344
#          Iterations 4
# fold 4, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693093
#          Iterations 3
# fold 4, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.693102
#          Iterations 3
# fold 4, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.692457
#          Iterations 3
# fold 4, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.677410
#          Iterations 4
# fold 4, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.693032
#          Iterations 3
# fold 4, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.674987
#          Iterations 5
# fold 4, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.683935
#          Iterations 4
# fold 4, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.625594
#          Iterations 6
# fold 4, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.504900
#          Iterations 6
# fold 4, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.657639
#          Iterations 5
# fold 4, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.691111
#          Iterations 4
# fold 4, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.681244
#          Iterations 4
# fold 4, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.691215
#          Iterations 4
# fold 4, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.692817
#          Iterations 3
# fold 4, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.692105
#          Iterations 4
# fold 4, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.689612
#          Iterations 4
# fold 4, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.691694
#          Iterations 4
# fold 4, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.664803
#          Iterations 5
# fold 4, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.676334
#          Iterations 4
# fold 4, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.676612
#          Iterations 4
# fold 4, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.639481
#          Iterations 5
# fold 5, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.611914
#          Iterations 5
# fold 5, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.691571
#          Iterations 4
# fold 5, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.690680
#          Iterations 4
# fold 5, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.675117
#          Iterations 4
# fold 5, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.687436
#          Iterations 4
# fold 5, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.692412
#          Iterations 3
# fold 5, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692237
#          Iterations 3
# fold 5, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.686198
#          Iterations 4
# fold 5, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.686804
#          Iterations 4
# fold 5, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.693008
#          Iterations 3
# fold 5, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.690514
#          Iterations 4
# fold 5, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.693133
#          Iterations 3
# fold 5, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692827
#          Iterations 3
# fold 5, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.691226
#          Iterations 4
# fold 5, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.692563
#          Iterations 3
# fold 5, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.681099
#          Iterations 4
# fold 5, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.685611
#          Iterations 4
# fold 5, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.682504
#          Iterations 4
# fold 5, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.688992
#          Iterations 4
# fold 5, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.692107
#          Iterations 4
# fold 5, biomarker = NRBC
# exog contains inf or nans
# fold 5, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.693063
#          Iterations 3
# fold 5, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.693062
#          Iterations 3
# fold 5, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693114
#          Iterations 3
# fold 5, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.693086
#          Iterations 3
# fold 5, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693123
#          Iterations 3
# fold 5, biomarker = NRBCP
# exog contains inf or nans
# fold 5, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.665435
#          Iterations 5
# fold 5, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.661161
#          Iterations 5
# fold 5, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.690444
#          Iterations 4
# fold 5, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.685544
#          Iterations 4
# fold 5, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.669607
#          Iterations 4
# fold 5, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.658294
#          Iterations 5
# fold 5, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.654133
#          Iterations 5
# fold 5, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.684046
#          Iterations 4
# fold 5, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.689644
#          Iterations 4
# fold 5, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.685269
#          Iterations 4
# fold 5, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.693099
#          Iterations 3
# fold 5, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.690582
#          Iterations 4
# fold 5, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.661196
#          Iterations 5
# fold 5, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.673925
#          Iterations 4
# fold 5, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.690379
#          Iterations 4
# fold 5, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.686598
#          Iterations 4
# fold 5, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693136
#          Iterations 3
# fold 5, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.691837
#          Iterations 3
# fold 5, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.692605
#          Iterations 3
# fold 5, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.677854
#          Iterations 4
# fold 5, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.693130
#          Iterations 3
# fold 5, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.682758
#          Iterations 5
# fold 5, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.681216
#          Iterations 4
# fold 5, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.631140
#          Iterations 6
# fold 5, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.505439
#          Iterations 6
# fold 5, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.652981
#          Iterations 5
# fold 5, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.690628
#          Iterations 4
# fold 5, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.682491
#          Iterations 4
# fold 5, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.693013
#          Iterations 3
# fold 5, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.693046
#          Iterations 3
# fold 5, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.691620
#          Iterations 4
# fold 5, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.691910
#          Iterations 3
# fold 5, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.692454
#          Iterations 3
# fold 5, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.668947
#          Iterations 5
# fold 5, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.672179
#          Iterations 4
# fold 5, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.680314
#          Iterations 4
# fold 5, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.645504
#          Iterations 5
# fold 6, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.614103
#          Iterations 5
# fold 6, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.689886
#          Iterations 4
# fold 6, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.690999
#          Iterations 4
# fold 6, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.674204
#          Iterations 4
# fold 6, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.691262
#          Iterations 4
# fold 6, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.693104
#          Iterations 3
# fold 6, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692926
#          Iterations 3
# fold 6, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.690019
#          Iterations 4
# fold 6, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.689583
#          Iterations 4
# fold 6, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.692584
#          Iterations 3
# fold 6, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.688743
#          Iterations 4
# fold 6, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.692823
#          Iterations 3
# fold 6, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692418
#          Iterations 3
# fold 6, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692959
#          Iterations 3
# fold 6, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.691098
#          Iterations 4
# fold 6, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.679121
#          Iterations 4
# fold 6, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.687848
#          Iterations 4
# fold 6, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.683141
#          Iterations 4
# fold 6, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.688801
#          Iterations 4
# fold 6, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.692351
#          Iterations 4
# fold 6, biomarker = NRBC
# exog contains inf or nans
# fold 6, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.692837
#          Iterations 3
# fold 6, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692375
#          Iterations 3
# fold 6, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693011
#          Iterations 3
# fold 6, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692907
#          Iterations 3
# fold 6, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693130
#          Iterations 3
# fold 6, biomarker = NRBCP
# exog contains inf or nans
# fold 6, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.666708
#          Iterations 5
# fold 6, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.665611
#          Iterations 5
# fold 6, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.693146
#          Iterations 3
# fold 6, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.691171
#          Iterations 4
# fold 6, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.669509
#          Iterations 4
# fold 6, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.658478
#          Iterations 5
# fold 6, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.657016
#          Iterations 5
# fold 6, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.687559
#          Iterations 4
# fold 6, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.690107
#          Iterations 4
# fold 6, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.686611
#          Iterations 4
# fold 6, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.692825
#          Iterations 3
# fold 6, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.691081
#          Iterations 4
# fold 6, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.669888
#          Iterations 5
# fold 6, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.675377
#          Iterations 4
# fold 6, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.688028
#          Iterations 4
# fold 6, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.686609
#          Iterations 4
# fold 6, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693136
#          Iterations 3
# fold 6, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.692492
#          Iterations 3
# fold 6, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.691945
#          Iterations 3
# fold 6, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.673249
#          Iterations 4
# fold 6, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.693053
#          Iterations 3
# fold 6, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.677571
#          Iterations 5
# fold 6, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.684902
#          Iterations 4
# fold 6, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.632810
#          Iterations 6
# fold 6, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.503964
#          Iterations 6
# fold 6, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.660327
#          Iterations 5
# fold 6, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.690021
#          Iterations 4
# fold 6, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.678112
#          Iterations 4
# fold 6, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.692521
#          Iterations 3
# fold 6, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.692743
#          Iterations 3
# fold 6, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.690603
#          Iterations 4
# fold 6, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.690234
#          Iterations 4
# fold 6, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.691779
#          Iterations 3
# fold 6, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.675487
#          Iterations 5
# fold 6, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.678381
#          Iterations 4
# fold 6, biomarker = Vitamin_D
# Optimization terminated successfully.
# ...
# fold 9, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.691788
#          Iterations 3
# fold 9, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.690809
#          Iterations 4
# fold 9, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.676350
#          Iterations 4
# fold 9, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.688673
#          Iterations 4
# fold 9, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.692690
#          Iterations 3
# fold 9, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692588
#          Iterations 3
# fold 9, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.687296
#          Iterations 4
# fold 9, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.688002
#          Iterations 4
# fold 9, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.692951
#          Iterations 3
# fold 9, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.690626
#          Iterations 4
# fold 9, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.692905
#          Iterations 3
# fold 9, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692320
#          Iterations 3
# fold 9, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692408
#          Iterations 3
# fold 9, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.692068
#          Iterations 3
# fold 9, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.672879
#          Iterations 5
# fold 9, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.686676
#          Iterations 4
# fold 9, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.686085
#          Iterations 4
# fold 9, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.689847
#          Iterations 4
# fold 9, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.691847
#          Iterations 4
# fold 9, biomarker = NRBC
# exog contains inf or nans
# fold 9, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.690966
#          Iterations 4
# fold 9, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.692804
#          Iterations 3
# fold 9, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.691535
#          Iterations 4
# fold 9, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.693094
#          Iterations 3
# fold 9, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693071
#          Iterations 3
# fold 9, biomarker = NRBCP
# exog contains inf or nans
# fold 9, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.659733
#          Iterations 5
# fold 9, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.656716
#          Iterations 5
# fold 9, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.692381
#          Iterations 3
# fold 9, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.687862
#          Iterations 4
# fold 9, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.669987
#          Iterations 4
# fold 9, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.653536
#          Iterations 5
# fold 9, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.650970
#          Iterations 5
# fold 9, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.685942
#          Iterations 4
# fold 9, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.692677
#          Iterations 3
# fold 9, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.685951
#          Iterations 4
# fold 9, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.692801
#          Iterations 3
# fold 9, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.686371
#          Iterations 4
# fold 9, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.663006
#          Iterations 5
# fold 9, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.671203
#          Iterations 5
# fold 9, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.690154
#          Iterations 4
# fold 9, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.688125
#          Iterations 4
# fold 9, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.693147
#          Iterations 2
# fold 9, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.693125
#          Iterations 3
# fold 9, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.691466
#          Iterations 4
# fold 9, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.676877
#          Iterations 4
# fold 9, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.693058
#          Iterations 3
# fold 9, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.677429
#          Iterations 5
# fold 9, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.686264
#          Iterations 4
# fold 9, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.635178
#          Iterations 6
# fold 9, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.494380
#          Iterations 6
# fold 9, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.652049
#          Iterations 5
# fold 9, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.691938
#          Iterations 3
# fold 9, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.681492
#          Iterations 4
# fold 9, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.693117
#          Iterations 3
# fold 9, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.693113
#          Iterations 3
# fold 9, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.691616
#          Iterations 4
# fold 9, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.687940
#          Iterations 4
# fold 9, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.690516
#          Iterations 4
# fold 9, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.667439
#          Iterations 5
# fold 9, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.672533
#          Iterations 4
# fold 9, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.682791
#          Iterations 4
# fold 9, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.642860
#          Iterations 5
# fold 10, biomarker = BMI
# Optimization terminated successfully.
#          Current function value: 0.609537
#          Iterations 5
# fold 10, biomarker = SBP
# Optimization terminated successfully.
#          Current function value: 0.691233
#          Iterations 4
# fold 10, biomarker = DBP
# Optimization terminated successfully.
#          Current function value: 0.690108
#          Iterations 4
# fold 10, biomarker = WBC
# Optimization terminated successfully.
#          Current function value: 0.675317
#          Iterations 4
# fold 10, biomarker = RBC
# Optimization terminated successfully.
#          Current function value: 0.688714
#          Iterations 4
# fold 10, biomarker = Hgb
# Optimization terminated successfully.
#          Current function value: 0.692882
#          Iterations 3
# fold 10, biomarker = Hct
# Optimization terminated successfully.
#          Current function value: 0.692669
#          Iterations 3
# fold 10, biomarker = MCV
# Optimization terminated successfully.
#          Current function value: 0.686541
#          Iterations 4
# fold 10, biomarker = MCH
# Optimization terminated successfully.
#          Current function value: 0.686403
#          Iterations 4
# fold 10, biomarker = MCHC
# Optimization terminated successfully.
#          Current function value: 0.692767
#          Iterations 3
# fold 10, biomarker = RDW
# Optimization terminated successfully.
#          Current function value: 0.690187
#          Iterations 4
# fold 10, biomarker = PLT
# Optimization terminated successfully.
#          Current function value: 0.693079
#          Iterations 3
# fold 10, biomarker = PCT
# Optimization terminated successfully.
#          Current function value: 0.692590
#          Iterations 3
# fold 10, biomarker = MPV
# Optimization terminated successfully.
#          Current function value: 0.692092
#          Iterations 3
# fold 10, biomarker = PDW
# Optimization terminated successfully.
#          Current function value: 0.691351
#          Iterations 4
# fold 10, biomarker = LYM
# Optimization terminated successfully.
#          Current function value: 0.682210
#          Iterations 4
# fold 10, biomarker = MONO
# Optimization terminated successfully.
#          Current function value: 0.685658
#          Iterations 4
# fold 10, biomarker = NEUT
# Optimization terminated successfully.
#          Current function value: 0.682907
#          Iterations 4
# fold 10, biomarker = EOS
# Optimization terminated successfully.
#          Current function value: 0.689191
#          Iterations 4
# fold 10, biomarker = BASO
# Optimization terminated successfully.
#          Current function value: 0.691964
#          Iterations 4
# fold 10, biomarker = NRBC
# exog contains inf or nans
# fold 10, biomarker = LYMP
# Optimization terminated successfully.
#          Current function value: 0.693125
#          Iterations 3
# fold 10, biomarker = MONOP
# Optimization terminated successfully.
#          Current function value: 0.693120
#          Iterations 3
# fold 10, biomarker = NEUTP
# Optimization terminated successfully.
#          Current function value: 0.693115
#          Iterations 3
# fold 10, biomarker = EOSP
# Optimization terminated successfully.
#          Current function value: 0.692935
#          Iterations 3
# fold 10, biomarker = BASOP
# Optimization terminated successfully.
#          Current function value: 0.693061
#          Iterations 3
# fold 10, biomarker = NRBCP
# exog contains inf or nans
# fold 10, biomarker = RETP
# Optimization terminated successfully.
#          Current function value: 0.662301
#          Iterations 5
# fold 10, biomarker = RET
# Optimization terminated successfully.
#          Current function value: 0.659986
#          Iterations 5
# fold 10, biomarker = MRV
# Optimization terminated successfully.
#          Current function value: 0.691396
#          Iterations 4
# fold 10, biomarker = MSCV
# Optimization terminated successfully.
#          Current function value: 0.685325
#          Iterations 4
# fold 10, biomarker = IRF
# Optimization terminated successfully.
#          Current function value: 0.671994
#          Iterations 4
# fold 10, biomarker = HLS_ReticP
# Optimization terminated successfully.
#          Current function value: 0.656390
#          Iterations 5
# fold 10, biomarker = HLS_Retic
# Optimization terminated successfully.
#          Current function value: 0.654158
#          Iterations 5
# fold 10, biomarker = Urine_creatinine
# Optimization terminated successfully.
#          Current function value: 0.688504
#          Iterations 4
# fold 10, biomarker = Urine_potassium
# Optimization terminated successfully.
#          Current function value: 0.692240
#          Iterations 3
# fold 10, biomarker = Urine_sodium
# Optimization terminated successfully.
#          Current function value: 0.687846
#          Iterations 4
# fold 10, biomarker = Albumin
# Optimization terminated successfully.
#          Current function value: 0.693084
#          Iterations 3
# fold 10, biomarker = ALP
# Optimization terminated successfully.
#          Current function value: 0.689356
#          Iterations 4
# fold 10, biomarker = ALT
# Optimization terminated successfully.
#          Current function value: 0.668155
#          Iterations 5
# fold 10, biomarker = ApoA
# Optimization terminated successfully.
#          Current function value: 0.671892
#          Iterations 4
# fold 10, biomarker = ApoB
# Optimization terminated successfully.
#          Current function value: 0.689340
#          Iterations 4
# fold 10, biomarker = AST
# Optimization terminated successfully.
#          Current function value: 0.688327
#          Iterations 4
# fold 10, biomarker = DBIL
# Optimization terminated successfully.
#          Current function value: 0.692798
#          Iterations 3
# fold 10, biomarker = Urea
# Optimization terminated successfully.
#          Current function value: 0.692873
#          Iterations 3
# fold 10, biomarker = Calcium
# Optimization terminated successfully.
#          Current function value: 0.692358
#          Iterations 3
# fold 10, biomarker = CHOL
# Optimization terminated successfully.
#          Current function value: 0.674548
#          Iterations 4
# fold 10, biomarker = Creatinine
# Optimization terminated successfully.
#          Current function value: 0.692811
#          Iterations 3
# fold 10, biomarker = CRP
# Optimization terminated successfully.
#          Current function value: 0.680981
#          Iterations 5
# fold 10, biomarker = CysC
# Optimization terminated successfully.
#          Current function value: 0.682525
#          Iterations 4
# fold 10, biomarker = Glucose
# Optimization terminated successfully.
#          Current function value: 0.632824
#          Iterations 6
# fold 10, biomarker = HbA1c
# Optimization terminated successfully.
#          Current function value: 0.503396
#          Iterations 6
# fold 10, biomarker = HDLc
# Optimization terminated successfully.
#          Current function value: 0.653023
#          Iterations 5
# fold 10, biomarker = IGF_1
# Optimization terminated successfully.
#          Current function value: 0.691052
#          Iterations 4
# fold 10, biomarker = LDLc
# Optimization terminated successfully.
#          Current function value: 0.679489
#          Iterations 4
# fold 10, biomarker = Lpa
# Optimization terminated successfully.
#          Current function value: 0.693100
#          Iterations 3
# fold 10, biomarker = Phosphate
# Optimization terminated successfully.
#          Current function value: 0.693144
#          Iterations 3
# fold 10, biomarker = TBIL
# Optimization terminated successfully.
#          Current function value: 0.692526
#          Iterations 3
# fold 10, biomarker = Testosterone
# Optimization terminated successfully.
#          Current function value: 0.690720
#          Iterations 4
# fold 10, biomarker = TP
# Optimization terminated successfully.
#          Current function value: 0.692249
#          Iterations 3
# fold 10, biomarker = TG
# Optimization terminated successfully.
#          Current function value: 0.670636
#          Iterations 5
# fold 10, biomarker = Urate
# Optimization terminated successfully.
#          Current function value: 0.675384
#          Iterations 4
# fold 10, biomarker = Vitamin_D
# Optimization terminated successfully.
#          Current function value: 0.683244
#          Iterations 4
# fold 10, biomarker = TyG
# Optimization terminated successfully.
#          Current function value: 0.644629
#          Iterations 5

# %%
# meta beta, se, p-value
beta_cv = np.mean(beta, axis=1)
se_cv = np.std(beta, axis=1) / np.sqrt(10)
# t-value
t_stats = beta_cv / (se_cv + 1e-9)
# p-value
p_values_cv = 2 * (1 - t.cdf(np.abs(t_stats), 10 - 1))

# %%
# save results
df_logit_cv = pd.DataFrame({
    'Biomarker': biomarkers, 
    'Beta': beta_cv, 
    'SE': se_cv, 
    't': t_stats, 
    'p-value': p_values_cv,
    'abs_beta': np.abs(beta_cv)
}).sort_values(by='abs_beta', ascending=False)
df_logit_cv = df_logit_cv.merge(df_bio_names, on='Biomarker', how='left')
df_logit_cv.to_csv(f'data/data_balanced/logistic/biomarker_logit_cv_{dm_type}.csv', index=False)
